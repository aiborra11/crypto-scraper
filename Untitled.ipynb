# %%
import pandas as pd
import datetime as dt
# import datetime

# %%
# data['timestamp'].loc['.682000']

# %%
data = pd.read_csv(f'./data/1H_2018-08-12.csv')
data
# Out:
#               timestamp       Size     GrossValue     Total_BTC    Total_USD  \
# 0   2018-08-12 01:00:00  297518140  4772162092496  47721.620925  297518140.0
# 1   2018-08-12 02:00:00   89122924  1423340821020  14233.408210   89122924.0
# 2   2018-08-12 03:00:00   43157341   687154882760   6871.548828   43157341.0
# 3   2018-08-12 04:00:00   30789688   490384073088   4903.840731   30789688.0
# 4   2018-08-12 05:00:00   37191873   593559020804   5935.590208   37191873.0
# 5   2018-08-12 06:00:00  144056634  2279305399957  22793.054000  144056634.0
# 6   2018-08-12 07:00:00   74590424  1177212460738  11772.124607   74590424.0
# 7   2018-08-12 08:00:00   68056484  1075877111805  10758.771118   68056484.0
# 8   2018-08-12 09:00:00   74225457  1176937813843  11769.378138   74225457.0
# 9   2018-08-12 10:00:00   57120383   904531051811   9045.310518   57120383.0
# 10  2018-08-12 11:00:00   66293402  1047165799948  10471.657999   66293402.0
# ...

# %%
data = pd.read_csv(f'./data/1H_2018-08-11.csv')
data
# Out:
#               timestamp        Size      GrossValue      Total_BTC  \
# 0   2018-08-11 01:00:00   265399346   4339857271102   43398.572711
# 1   2018-08-11 02:00:00   203410030   3334690637022   33346.906370
# 2   2018-08-11 03:00:00   173410720   2835179738428   28351.797384
# 3   2018-08-11 04:00:00   139867424   2290472416728   22904.724167
# 4   2018-08-11 05:00:00   253052910   4143753733796   41437.537338
# 5   2018-08-11 06:00:00   537540818   8861416317016   88614.163170
# 6   2018-08-11 07:00:00   225506706   3705300761848   37053.007618
# 7   2018-08-11 08:00:00   237849978   3905310148974   39053.101490
# 8   2018-08-11 09:00:00   204563804   3342308030492   33423.080305
# 9   2018-08-11 10:00:00   112381334   1841095477012   18410.954770
# 10  2018-08-11 11:00:00   235614084   3838709871402   38387.098714
# 11  2018-08-11 12:00:00   205995700   3373933431440   33739.334314
# 12  2018-08-11 13:00:00   297343912   4870904204922   48709.042049
# ...

# %%
data = pd.read_csv(f'./data/raw_20180812_20180812.csv')
print(len(data))
# data = pd.read_csv(f'./data/raw_20180824_20180825.csv')
# data
# Out:
# /usr/local/Cellar/ipython/7.3.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 3184380

# %%
data.isnull().sum(axis = 0)
# Out:
# Unnamed: 0         0
# _id                0
# timestamp          0
# symbol             0
# side               0
# size               1
# price              1
# tickDirection      1
# trdMatchID         1
# grossValue         1
# homeNotional       1
# foreignNotional    1
# dtype: int64

# %%
data.head(25474200)
# Out:
#          Unnamed: 0                       _id                   timestamp  \
# 0                 0  5f5e47849139518cf4ccc94e  2018-08-12 00:00:03.682000
# 3184376     3184376  5f68f40530972aed03613034  2018-08-12 23:59:59.858000
# 3184377     3184377  5f68f40530972aed03613035  2018-08-12 23:59:59.858000
# 3184378     3184378  5f68f40530972aed03613036  2018-08-12 23:59:59.858000
# 3184379     3184379  5f68f40530972aed03613037  2018-08-12 23:59:59.858000
#
#          symbol  side   size   price  tickDirection  \
# ...

# %%
df1 = data[data['timestamp'].isna()].drop('timestamp', 
                                          inplace=True)
print (df1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-b4926eb84cbd> in <module>
#       1 df1 = data[data['timestamp'].isna()].drop('timestamp',
# ----> 2                                           inplace=True)
#       3 print (df1)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
for i in data.timestamp[636875:]:
    print(i[:19].replace('D', ' '))
# Out:
# 2018-08-12 23:59:59
# 2018-08-12 00:00:03
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:04
# 2018-08-12 00:00:05
# 2018-08-12 00:00:05
# 2018-08-12 00:00:05
# 2018-08-12 00:00:05
# 2018-08-12 00:00:05
# 2018-08-12 00:00:06
# ...

# %%
data.timestamp
# Out:
# 0          2018-08-12 00:00:03.682000
# 1          2018-08-12 00:00:04.047000
# 2          2018-08-12 00:00:04.047000
# 3          2018-08-12 00:00:04.047000
# 4          2018-08-12 00:00:04.047000
#                       ...
# 1348280    2018-08-12 01:32:00.548000
# 1348281    2018-08-12 01:32:00.682000
# 1348282    2018-08-12 01:32:00.731000
# 1348283    2018-08-12 01:32:02.394000
# 1348284    2018-08-12 01:32:03.124000
# Name: timestamp, Length: 1348285, dtype: object

# %%
# data['timestamp'] = data['timestamp'].map(lambda t: datetime.datetime.strptime(t, f).strftime('%Y-%m-%d %H:%M:%S.%f'))

# d = data['timestamp'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f'))

# try:

data['timestamp'] = data['timestamp'].map(lambda x: dt.datetime.strptime(str(x[:19].replace('D', ' ')), '%Y-%m-%d %H:%M:%S'))                              
                             

# except:
#     data['timestamp'] = data['timestamp'].map(lambda x: dt.datetime.strptime(x[:19], '%Y-%m-%d %H:%M:%S'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c67099372fc9> in <module>
#       5
#       6 # try:
# ----> 7 data['timestamp'] = data['timestamp'].map(lambda x: dt.datetime.strptime(str(x[:19].replace('D', ' ')), '%Y-%m-%d %H:%M:%S'))
#       8
#       9
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# /usr/local/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# ...

# %%
date_format = ['%Y-%m-%d %H:%M:%S.%f']
for f in date_format:
#     try:
    data['timestamp'] = data['timestamp'].map(lambda t: datetime.datetime.strptime(t, f).strftime('%Y-%m-%d %H:%M:%S.%f'))

#         data['timestamp'] = datetime.datetime.strptime(data['timestamp'], f).strftime('%Y-%m-%d %H:%M:%S.%f')
#     except:
#         print('cannot convert data')
#         continue
#     else:
#         break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-334f9ed40419> in <module>
#       2 for f in date_format:
#       3 #     try:
# ----> 4     data['timestamp'] = data['timestamp'].map(lambda t: datetime.datetime.strptime(t, f).strftime('%Y-%m-%d %H:%M:%S.%f'))
#       5
#       6 #         data['timestamp'] = datetime.datetime.strptime(data['timestamp'], f).strftime('%Y-%m-%d %H:%M:%S.%f')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# /usr/local/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1143
# ...

# %%
data.head(1014)
# Out:
#       Unnamed: 0                       _id                   timestamp  \
# 0              0  5f5e47849139518cf4ccc94e  2018-08-12 00:00:03.682000
# 1              1  5f5e47849139518cf4ccc94f  2018-08-12 00:00:04.047000
# 2              2  5f5e47849139518cf4ccc950  2018-08-12 00:00:04.047000
# 3              3  5f5e47849139518cf4ccc951  2018-08-12 00:00:04.047000
# 4              4  5f5e47849139518cf4ccc952  2018-08-12 00:00:04.047000
# ...          ...                       ...                         ...
# 1009        1009  5f5e47849139518cf4cccd3f  2018-08-12 00:00:31.782000
# 1010        1010  5f5e47849139518cf4cccd40  2018-08-12 00:00:31.844000
# 1011        1011  5f5e47849139518cf4cccd41  2018-08-12 00:00:31.937000
# 1012        1012  5f5e47849139518cf4cccd42         2018-08-12 00:00:32
# 1013        1013  5f5e47849139518cf4cccd43  2018-08-12 00:00:32.038000
#
#       symbol  side  size   price  tickDirection  \
# 0     XBTUSD   Buy  1000  6241.0   ZeroPlusTick
# ...

# %%
data2 = pd.read_csv(f'./data/raw_20180811_20180811.csv')
data2
# Out:
#          Unnamed: 0                       _id                timestamp  \
# 0                 0  5f5e47599139518cf4c2be1a  2018-08-11 00:00:03.002
# 1                 1  5f5e47599139518cf4c2be1b  2018-08-11 00:00:03.421
# 2                 2  5f5e47599139518cf4c2be1c  2018-08-11 00:00:03.658
# 3                 3  5f5e47599139518cf4c2be1d  2018-08-11 00:00:03.780
# 4                 4  5f5e47599139518cf4c2be1e  2018-08-11 00:00:03.796
# ...             ...                       ...                      ...
# 1316451     1316451  5f5e492d5891278f2e33b2d5  2018-08-11 23:59:59.917
# 1316452     1316452  5f5e492d5891278f2e33b2d6  2018-08-11 23:59:59.917
# 1316453     1316453  5f5e492d5891278f2e33b2d7  2018-08-11 23:59:59.917
# 1316454     1316454  5f5e492d5891278f2e33b2d8  2018-08-11 23:59:59.917
# 1316455     1316455  5f5e492d5891278f2e33b2d9  2018-08-11 23:59:59.917
#
#          symbol side   size   price tickDirection  \
# 0        XBTUSD  Buy   1000  6138.0  ZeroPlusTick
# ...
